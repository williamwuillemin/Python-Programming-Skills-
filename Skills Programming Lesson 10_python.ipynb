# %% [markdown]
# <a href="https://colab.research.google.com/github/williamwuillemin/Python-Programming-Skills-/blob/main/Skills%20Programming%20Lesson%2010_python.ipynb" target="_parent"><img src="https://colab.research.google.com/assets/colab-badge.svg" alt="Open In Colab"/></a>

# %% [markdown]
# # Python Skills Lesson 10 - File handling

# %%
# Task 1
# Out:
# /tmp/ipykernel_648/1749080446.py:26: FutureWarning: YF.download() has changed argument auto_adjust default to True
#   df = yf.download(stocks, start = start, end = end)          # use the function of the yf packages instead because google does not work (extract the data and add it to the dataset df)
# [*********************100%***********************]  4 of 4 completed
# Total Volume Traded in 2015
#          Apple:        52,264,199,600 shares
#            IBM:         1,156,439,400 shares
#      Microsoft:         9,059,455,900 shares
#          Tesla:        16,323,267,000 shares
