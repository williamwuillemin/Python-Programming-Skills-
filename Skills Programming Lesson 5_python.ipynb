# %% [markdown]
# <a href="https://colab.research.google.com/github/williamwuillemin/Python-Programming-Skills-/blob/main/Skills%20Programming%20Lesson%205_python.ipynb" target="_parent"><img src="https://colab.research.google.com/assets/colab-badge.svg" alt="Open In Colab"/></a>

# %% [markdown]
# Skills Programming - Lesson 5 Strings

# %%
# Task 1
s = input("Please give me a sentence: ")
letter = input("Please give me a letter or number to count: ")      # both input for the sentence and which letter do we want print(len(s.split()))

word = (len(s.split()))                                               # split the word and then only count the lenght of the list                                              # split the word and only count then the lenght of the list
print(word)

if len(letter) != 1:                                                # needed to add 1 otherwise one could put directly a word an not a letter so now it only count the letter
    print("Please enter exactly one letter.")
else:                                                               # transform all the letter in lowercase in order to be also able to count the first letter of a name for example
    letter_c = s.lower().count(letter.lower())
    print(letter_c)

# note that we do not need any try / except because we only count number or strange sign in the sentence and they are all store as a string

print(f"The sentence countains {word} words and has {letter_c} letter {letter}.")         # simply the final output of the code so it looks nice
# Out:
# Please give me a sentence: My name is William walter Wuillemin
# Please give me a letter or number to count: w
# 6
# 3
# The sentence countains 6 words and has 3 letter w.

# %%
# Task 2
e = input("Enter the equation (such as 1 + 1 = 2): ")               # equation with which we need to play

result = (e.replace("0", "zero").replace("1", "one").replace("2", "two").replace("3", "three").replace("4", "four").replace("5", "five").replace("6", "six").replace("7", "seven").replace("8", "eight")
        .replace("9", "nine"))        # replace all the number by a word-number

print(result) # simply print the final result
# Out:
# Enter the equation (such as 1 + 1 = 2): 5 + 6 = 11
# five + six = oneone

# %%
# Task 3:
# Modify the below program so it prints the number of 'a's within the string
# and converts everything to uppercase and lowercase.
s = "Strings are awesome!"

# Length should be 20
print("Length of s = %d" % len(s))

# Number of a's should be 2
# print("a occurs times:")
print(f"a occurs times: {s.count("a")}")

# Convert everything to uppercase
s_big = s.upper()
print("String in uppercase: %s" %s_big)

# Convert everything to lowercase
s_small = s.lower()
print("String in lowercase: %s" %s_small)
# Out:
# Length of s = 20
# a occurs times: 2
# String in uppercase: STRINGS ARE AWESOME!
# String in lowercase: strings are awesome!
