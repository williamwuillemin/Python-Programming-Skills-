# %% [markdown]
# <a href="https://colab.research.google.com/github/williamwuillemin/Python-Programming-Skills/blob/main/Skills%20Programming%20Lesson%207_python.ipynb" target="_parent"><img src="https://colab.research.google.com/assets/colab-badge.svg" alt="Open In Colab"/></a>

# %% [markdown]
# Skills Programming - Lesson 7 Loops

# %%
# Task 1
try:                                                                            # safety net (valid input)
  a = input("Please enter numbers (separated by a comma): ").split(",")         # input from the user separated by a comma
  numbers = []                                                                  # create the empty list in which we are going to store them
  for item in a:                                                                # for loops that goes through each input and transform it into an integer that is then store in a list number
    item = item.strip()
    numbers.append(int(item))
  print(f"The sum of your input is {sum(numbers)}.")                            # simply print the sum of all the number inside
except ValueError:
  print("Please enter numbers separated by a comma")                            # handle wrong input like letter
# Out:
# Please enter numbers (separated by a comma): please,4,3,2,5
# Please enter numbers separated by a comma

# %%
# Task 1 (different interpretation)
a = input("Please enter numbers (separated by a comma): ").split(",")     # input from the user
total = 0                                                                 # starting point to which we are going to add it
for item in a:                                                            # for loop that goes through all input, transform them into integer, and add them to the total
  try:                                                                    # use the safety net as a conditional in order to only keep the right input (letter are not accepted)
    item = item.strip()
    total += int(item)
  except ValueError:
    print(f"We are skipping the entry {item} as it is not a valid one")   # handle the issue

print(f"The total sum of the numbers given is {total}")                   # print the result
# Out:
# Please enter numbers (separated by a comma): a,2,3,4,5,6,5,4
# We are skipping the entry a as it is not a valid one
# The total sum of the numbers given is 29

# %%
# Task 1 (other options)
a = input("Please enter numbers (separated by a comma): ").split(",")                         # takes the list of input and make sure they are split (using the comma)
total = 0                                                                                     # create the inital sum of value in which we are going to store the additional
for item in a:                                                                                # the loop that goes through each element given as input one by one
    item = item.strip()                                                                       # need to add this because the program consider the input as an invalid input (remove the spacing)
    while True:                                                                               # as long as the there is an input the loops keeps adding them but one there is none any more the loops stop
        try:                                                                                  # this is the part that makes sure that all the input are valid, before transforming the string into integer and summing them
            total += int(item)
            break                                                                             # valid input, move to next item
        except ValueError:
            item = input(f"The input {item} is not valid. Please enter a valid input: ")      # invalid input are isolated and the program asks to the user to replace the input in order to have a new compelete list. Note that it can also skip the item simply using: print(f"We are skipping the entry {item} as it is not a valid one")

print(f"The total sum of the numbers given is {total}")                                       # return the final sum
# Out:
# Please enter numbers (separated by a comma): 3,2,a
# The input a is not valid. Please enter a valid input: 10
# The total sum of the numbers given is 15

# %%
# Task 2

def sumofthree():
# this is the definition of the function
  try:
# add the try: protection in order to protect the program if the user decide to separate by something else than a comma or if the user uses sign $ or characters instead of numbers
    a,b,c = input(f"Please enter three numbers (separated by a comma (Example: 1,2,3)): ").strip().split(",")
# this is the input function that ask the user to plug three numbers (note that another options would be to put the input directly inside the function such as sumofthree(1,2,3) but this version is more interactive)
# we remove the spacing and split the input by the comma
    numbers = []                                    # create an empty list in which we are going to put the transformed input
    for x in [a,b,c]:                               # create a for loop in order to be able to take both float and integers and obtain the sum of both (not only one type)
      if "." in x:                                  # we differentiate the two sort by the dot that only the float contain
        numbers.append(float(x))                    # when have a dot then we transform the input into a float
      else:
        numbers.append(int(x))                      # when it does not contain any dot then we know it is an integer
# note that if the input is not an integer or a float (the program cannot transform it and it does to the expect ValueError)
    sum = numbers[0] + numbers[1] + numbers[2]      # this is the sum of the three component of the transformed output
    print(f"The sum of {a}, {b} and {c} is {sum}.") # print the result
  except ValueError:                                # as mentioned is here in case of invalid input
    print("Error: Please enter three numbers separated by a comma (,)")




sumofthree()                                        # invoke the function
# Out:
# Please enter three numbers (separated by ,(Example: 1,2,3)): 1.2,2,4
# The sum of 1.2, 2 and 4 is 7.2.

# %%
# Task 2 (other simpler version)

def sumofthree(a,b,c):
# this is the definition of the function
  try:
# add the try: protection in order to protect the program if the user decide to separate by something else than a comma or if the user uses sign $ or characters instead of numbers
    numbers = []                                    # create an empty list in which we are going to put the transformed input
    for x in [a,b,c]:                               # create a for loop in order to be able to take both float and integers and obtain the sum of both (not only one type)
# note that we need to transform into a string otherwise the program is not able to identify the dot
      if "." in str(x):                             # we differentiate the two sort by the dot that only the float contain
        numbers.append(float(x))                    # when have a dot then we transform the input into a float
      else:
        numbers.append(int(x))                      # when it does not contain any dot then we know it is an integer
# note that if the input is not an integer or a float (the program cannot transform it and it does to the expect ValueError)
    sum = numbers[0] + numbers[1] + numbers[2]      # this is the sum of the three component of the transformed output
    print(f"The sum of {a}, {b} and {c} is {sum}.") # print the result
  except ValueError:                                # as mentioned is here in case of invalid input
    print("Error: Please enter three numbers separated by a comma (,)")

sumofthree(1,2,3 )
# Out:
# The sum of 1, 2 and 3 is 6.

# %%
# Task 2 Basic options

def sumofthree(a, b, c):                                        # using the basic options with the three input directly in the function
        result = sum([a,b,c])                                   # sum of the input
        # equivalent to result = float(a) + float(b) + float(c) simply with a build in function
        print(f"The sum of {a}, {b} and {c} is {result}.")      # print the result


# invoke the function
sumofthree(1,2,3)
sumofthree(1,2.3,4)
# sumofthree(1,2,$) or sumofthree(1,2,f) won't work becuase it is not an integer
# Out:
# The sum of 1, 2 and 3 is 6.
# The sum of 1, 2.3 and 4 is 7.3.

# %%
# Task 2

def sumofthree():
# this is the definition of the function
  try:
# add the try: protection in order to protect the program if the user decide to separate by something else than a comma or if the user uses sign $ or characters instead of numbers
    a,b,c = input(f"Please enter three numbers (separated by a comma (Example: 1,2,3)): ").strip().split(",")
# this is the input function that ask the user to plug three numbers (note that another options would be to put the input directly inside the function such as sumofthree(1,2,3) but this version is more interactive)
# we remove the spacing and split the input by the comma
    numbers = []                                    # create an empty list in which we are going to put the transformed input
    for x in [a,b,c]:                               # create a for loop in order to be able to take both float and integers and obtain the sum of both (not only one type)
      if "." in x:                                  # we differentiate the two sort by the dot that only the float contain
        numbers.append(float(x))                    # when have a dot then we transform the input into a float
      else:
        numbers.append(int(x))                      # when it does not contain any dot then we know it is an integer
# note that if the input is not an integer or a float (the program cannot transform it and it does to the expect ValueError)
#sum = numbers[0] + numbers[1] + numbers[2]      # this is the sum of the three component of the transformed output
    result = sum(numbers)
    print(f"The sum of {a}, {b} and {c} is {result}.") # print the result
  except ValueError:                                # as mentioned is here in case of invalid input
    print("Error: Please enter three numbers separated by a comma (,)")




sumofthree()                                        # invoke the function
# Out:
# Please enter three numbers (separated by a comma (Example: 1,2,3)): 1,2,3
# The sum of 1, 2 and 3 is 6.

# %%
# Task 3
# debug the below program and fix what is wrong so it prints all numbers.

"""
prime = [2, 3, 5, 7]                       # create a list of element
for x in prime:                            # the loop for goes through each element in the prime list
    print(x)                               # print the x
"""

# improved version
"""
We define prime number as positive integers greater than 1 (wikipedia)
"""
# we are going to proceed in three step:

# first we need to identify the right prime number
# second we want to store the prime number in a list
# finally we want to print the created list of the prime number given the limit of the user

                                      # this first function is here to answer the question is x a prime number
def loc_prime(x):                     # we check for every number in the limit
    if x <= 2:                        # it check that the x is bigger than 2 (accroding to wikipedia 1 is not a prime number)
      return False
    for i in range(2, x):             # it check that it is not perfectly divisible (definition of a prime number)
      if x % i == 0:
        return False
    return True                       # if none of the before mentioned condition are fullfield it consider that the return is True (is a prime number)
                                      # note that we do check for every x in the limit as a prime number

                                      # now that we have identify we simply need to add the prime number in a list
def c_prime(limit):                   # this function is very simply is simply add the number to the prime list if the above function identify it as a prime number
  prime = []                          # the storage list of new prime number
  for x in range(2, limit + 1):       # we just need to limit the function by the limit that the user is going to give us: otherwise it run forever if use x in range(2,x + 1) (the +1 is here due to the existance of [0]). Now the limit (that the user choose is the )
    if loc_prime(x) == True:          # use the answer of the previous function to know if prime or not
      prime.append(x)                 # we add the prime number to the list
  return prime                        # return the list

                                                                                                     # the input and printing part
def print_prime():                                                                                   # now that we have prime we want to print the prime in the limit given by the user
  try:                                                                                               # make sure that the limit is valid (the user don't give us a "hello" for example)
    limit = int(input("Please enter the limit until which you want to find the prime number : "))    # simply the input function
    prime = c_prime(limit)                                                                           # we create a list with all the prime number given the limit
    if prime:                                                                                        # check that we have a prime in the limit given by the user
      print(f"They are {len(prime)} prime numbers up to {limit}")                                    # we just make sure that the program works and give us a prime (note that if the user give us the limit 1 there is no prime in this number)
      for i,P_num in prime:
        print(f"Prime {i}: {P_num}")                                                                 # use the loops to print all the prime number (note that it also print which prime number is it is like prime number nr.1 is 2 --- etc..-)
    else:
      print("No prime numbers found in that range.")                                                 # the case where the user give us a number that is negative as a limit (or simply below than to (]infinity;1] does not contain any prime number))
  except ValueError:                                                                                 # if the user give a letter instead of a number as a limit
    print("Please enter a valid limit")


# invoke the function
print_prime()
# Out:
# Please enter the limit until which you want to find the prime number : -1
# No prime numbers found in that range.
