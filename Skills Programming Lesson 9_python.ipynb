# %% [markdown]
# <a href="https://colab.research.google.com/github/williamwuillemin/Python-Programming-Skills-/blob/main/Skills%20Programming%20Lesson%209_python.ipynb" target="_parent"><img src="https://colab.research.google.com/assets/colab-badge.svg" alt="Open In Colab"/></a>

# %% [markdown]
# # Python Skills Programming Lesson 9

# %%
# Task 1
# Debug and modify the below program so it prints the string in the following format
# input: Fred, 4
# output:
# Fred
# Fred Fred
# Fred Fred Fred
# Fred Fred Fred Fred
# There are 3 mistakes in this code - FIX them
def prlines(text, num):
    for n in range(0, num):
        print((text + " ") * (n + 1))
prlines("Fred", 4)



# Improvement in the code:
def prlines2():                                                                 # definition of the function
    try:                                                                        # safety net in case you give two words instead of a words and a number
      text, num = input("""
      Enter a word that you want to see written
      and give the number of time that you want to see the word repeated
      (separate both by a comma):
      """).strip().split(",")                                                   # just try to improve the presentation of the input message (make it less long so that the code can be read directly)
      num = int(num)                                                            # transform the input string of the number into a concrete integer to be able to compute the repetition
      if num <= 0:                                                              # make sure that the number is positive to compute the true number of repetition (cannot repeat -3 times the words Hi)
          print("Please enter a positive number")                               # error message
          return
      if not text:                                                              # make sure that the user enter a name and not simply skip a part
          print("Name cannot be empty. Please give us a name")                  # error message
          return
      for n in range(0, num):                                                   # loop to compute the number of repetition
          print((text + " ") * (n + 1))
    except ValueError:                                                          # final error message in case two words input (or if forget to put a number)
        print("Please enter a valid number")

# invoke function
prlines2()
# Out:
# Fred
# Fred Fred
# Fred Fred Fred
# Fred Fred Fred Fred
#
#       Enter a word that you want to see written
#       and give the number of time that you want to see the word repeated
#       (separate both by a comma):
#       Hi , 5
# Hi
# Hi  Hi
# Hi  Hi  Hi
# Hi  Hi  Hi  Hi
# Hi  Hi  Hi  Hi  Hi

# %%
# Task 2 Instruction:
# This gets the random number generator.
# There are 3 mistakes in this code - FIX them

import random

i = random.randrange(10, 50)
print('Your number is', i + 1)

if i < 20:
    print("That is less than 20.")
if i % 3 == 0:
    print("It is divisible by 3.")
elif i == 20:
    print("That is exactly twenty. How nice for you.")
else:
    if i % 2 == 1:
        print("That is an odd number.")
    else:
        print("That is twice", i / 2, '.')
    print("Wow! That's more than 20!")

# %%
# Task 2
# This gets the random number generator.
# There are 3 mistakes in this code - FIX them

import random                                                 # import the package to have the random function (give us random number)

i = random.randrange(10, 51)                                  # use from random the function randrange between 10 and 50 (including both otherwise 10 to 50 it is only 10 to 49 hence the 51)
print('Your number is', i)                                    # print the exact number (no need to add + 1 to go to 50 (note that the + 1 make it impossible to have 10 because we direcly have 11))
                                                              # we have [10 - 50]
if i < 20:                                                    # if : simply check that it is bigger smaller than 20
    print("That is less than 20.")                            # this leaves us for the rest [20 - 50]
if i % 3 == 0:                                                # if : we need to use if as well because a number can be smaller than 20 and also divisible by 3 (example: 12) so it need to return true in both case
    print("It is divisible by 3.")
elif i == 20:                                                 # elif : check if it is equal to 20
    print("That is exactly twenty. How nice for you.")        # this leaves us for the rest with [21 - 50]
else:
    if i % 2 == 1:                                            # if it does not enter into one of the category mentioned above, we check if it is an odd number
        print("That is an odd number.")                       # [21,23,25,27,29,31,33,35,37,39,41,43,45,47,49]
    else:
        print("That is twice", (i // 2), '.')                 # because we are only analysing the even number we can divide by // because we will have entier number
    print("Wow! That's more than 20!")                        # [22,24,26,28,30,32,34,36,38,40,42,44,46,48,50]
# Out:
# Your number is 23
# That is an odd number.
# Wow! That's more than 20!

# %%
# Task 2
# This gets the random number generator.
# There are 3 mistakes in this code - FIX them

import random                                                 # import the package to have the random function (give us random number)


# we are sorting all the value
i = random.randrange(10, 51)                                  # use from random the function randrange between 10 and 50 (including both otherwise 10 to 50 it is only 10 to 49 hence the 51)
print('Your number is', i)                                    # print the exact number (no need to add + 1 to go to 50 (note that the + 1 make it impossible to have 10 because we direcly have 11))
                                                              # remaining [10 - 50]
if i < 20:                                                    # if : simply check that it is bigger smaller than 20
    print("That is less than 20.")                            # remaining [20 - 50]
elif i % 3 == 0:                                              # elif : we are removing the case where they are divisible by three
    print("It is divisible by 3.")                            # remaining [20,22,23,25,26,28,29,31,32,34,35,37,38,40,41,43,44,46,47,49,50]
elif i == 20:                                                 # elif : check if it is equal to 20
    print("That is exactly twenty. How nice for you.")        # remaining [22,23,25,26,28,29,31,32,34,35,37,38,40,41,43,44,46,47,49,50]
else:
    if i % 2 == 1:                                            # if it does not enter into one of the category mentioned above, we check if it is an odd number -> [23,25,29,31,35,37,41,43,47,49]
        print("That is an odd number.")                       # remaining [22,26,28,32,34,38,40,44,46,50]
    else:
        print("That is twice", (i // 2), '.')                 # because we are only analysing the even number we can divide by // because we will have entier number -> [22,26,28,32,34,38,40,44,46,50]
                                                              # all the value have been sorted
    print("Wow! That's more than 20!")                        # it does not matter if the value are odd or even they are both over 20

# %%
# Task 2 complete restructure
# This gets the random number generator.
# There are 3 mistakes in this code - FIX them

import random                                                 # import the package to have the random function (give us random number)


# we are sorting all the value and change the stucture of the code

i = random.randrange(10, 51)                              # use from random the function randrange between 10 and 50 (including both otherwise 10 to 50 it is only 10 to 49 hence the 51)
print('Your number is', i)                                # print the exact value

if i < 20:                                                # check if below 20
    print("That is less than 20.")

elif i == 20:                                             # check if exclty equal to 20
    print("That is exactly twenty. How nice for you.")
    print("Wow! That's more than 20!")                    # all the value are above 20 -> remaining : [21-50]

elif i % 3 == 0:                                          # check if divisible by 3
    print("It is divisible by 3.")
                                                          # -> remaining : [22, 23, 25, 26, 28, 29, 31, 32, 34, 35, 37, 38, 40, 41, 43, 44, 46, 47, 49, 50]
else:                                                     # need to analyse the rest
    if i % 2 == 1:
        print("That is an odd number.")                   # remove the odd value
                                                          # -> remaining : [22, 26, 28, 32, 34, 38, 40, 44, 46, 50]
    else:
        print("That is twice", (i // 2), '.')             # all the value remaining are only even number so the division by 2 result in normal number (complete) hence the // it will render full integer in any case

    print("Wow! That's more than 20!")                    # we already know that all the value are going to be bigger than 20
